# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
import seaborn as sns
# %matplotlib inline
warnings.filterwarnings('ignore')
# %precision 2
# Out:
# '%.2f'

# %% [markdown]
# **Importing Libraries**

# %%
df= pd.read_csv('Hospital General Information.csv')
df.head(5)
# Out:
#    Provider ID                     Hospital Name                     Address  \
# 0        10001  SOUTHEAST ALABAMA MEDICAL CENTER      1108 ROSS CLARK CIRCLE
# 1        10005     MARSHALL MEDICAL CENTER SOUTH  2505 U S HIGHWAY 431 NORTH
# 2        10006    ELIZA COFFEE MEMORIAL HOSPITAL          205 MARENGO STREET
# 3        10007          MIZELL MEMORIAL HOSPITAL               702 N MAIN ST
# 4        10008       CRENSHAW COMMUNITY HOSPITAL         101 HOSPITAL CIRCLE
#
#        City State  ZIP Code County Name  Phone Number         Hospital Type  \
# 0    DOTHAN    AL     36301     HOUSTON    3347938701  Acute Care Hospitals
# 1      BOAZ    AL     35957    MARSHALL    2565938310  Acute Care Hospitals
# 2  FLORENCE    AL     35631  LAUDERDALE    2567688400  Acute Care Hospitals
# 3       OPP    AL     36467   COVINGTON    3344933541  Acute Care Hospitals
# 4   LUVERNE    AL     36049    CRENSHAW    3343353374  Acute Care Hospitals
#
# ...

# %%
df.isnull().sum()
# Out:
# Provider ID                                                         0
# Hospital Name                                                       0
# Address                                                             0
# City                                                                0
# State                                                               0
# ZIP Code                                                            0
# County Name                                                        15
# Phone Number                                                        0
# Hospital Type                                                       0
# Hospital Ownership                                                  0
# Emergency Services                                                  0
# Meets criteria for meaningful use of EHRs                         143
# Hospital overall rating                                             0
# ...

# %% [markdown]
# **Total null values in each column**

# %%
df.fillna(0).head()
# Out:
#    Provider ID                     Hospital Name                     Address  \
# 0        10001  SOUTHEAST ALABAMA MEDICAL CENTER      1108 ROSS CLARK CIRCLE
# 1        10005     MARSHALL MEDICAL CENTER SOUTH  2505 U S HIGHWAY 431 NORTH
# 2        10006    ELIZA COFFEE MEMORIAL HOSPITAL          205 MARENGO STREET
# 3        10007          MIZELL MEMORIAL HOSPITAL               702 N MAIN ST
# 4        10008       CRENSHAW COMMUNITY HOSPITAL         101 HOSPITAL CIRCLE
#
#        City State  ZIP Code County Name  Phone Number         Hospital Type  \
# 0    DOTHAN    AL     36301     HOUSTON    3347938701  Acute Care Hospitals
# 1      BOAZ    AL     35957    MARSHALL    2565938310  Acute Care Hospitals
# 2  FLORENCE    AL     35631  LAUDERDALE    2567688400  Acute Care Hospitals
# 3       OPP    AL     36467   COVINGTON    3344933541  Acute Care Hospitals
# 4   LUVERNE    AL     36049    CRENSHAW    3343353374  Acute Care Hospitals
#
# ...

# %% [markdown]
# **Filling null values with Zero**

# %%
del df['Hospital overall rating footnote']
del df['Mortality national comparison footnote']
del df['Safety of care national comparison footnote']
del df['Readmission national comparison footnote']
del df['Patient experience national comparison footnote']
del df['Timeliness of care national comparison footnote']
del df['Efficient use of medical imaging national comparison footnote']
del df['Effectiveness of care national comparison footnote']
df.head()
# Out:
#    Provider ID                     Hospital Name                     Address  \
# 0        10001  SOUTHEAST ALABAMA MEDICAL CENTER      1108 ROSS CLARK CIRCLE
# 1        10005     MARSHALL MEDICAL CENTER SOUTH  2505 U S HIGHWAY 431 NORTH
# 2        10006    ELIZA COFFEE MEMORIAL HOSPITAL          205 MARENGO STREET
# 3        10007          MIZELL MEMORIAL HOSPITAL               702 N MAIN ST
# 4        10008       CRENSHAW COMMUNITY HOSPITAL         101 HOSPITAL CIRCLE
#
#        City State  ZIP Code County Name  Phone Number         Hospital Type  \
# 0    DOTHAN    AL     36301     HOUSTON    3347938701  Acute Care Hospitals
# 1      BOAZ    AL     35957    MARSHALL    2565938310  Acute Care Hospitals
# 2  FLORENCE    AL     35631  LAUDERDALE    2567688400  Acute Care Hospitals
# 3       OPP    AL     36467   COVINGTON    3344933541  Acute Care Hospitals
# 4   LUVERNE    AL     36049    CRENSHAW    3343353374  Acute Care Hospitals
#
# ...

# %% [markdown]
# **Deleting Columns which are not necessary.**
#
# **Representing Data of dataset.**

# %%
sns.set(rc={'figure.figsize':(10,7)})
sns.heatmap(df.isnull(),yticklabels=False,cmap='magma',cbar=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Heatmap presenting null values in each column**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4812 entries, 0 to 4811
# Data columns (total 20 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Provider ID                                           4812 non-null   int64
#  1   Hospital Name                                         4812 non-null   object
#  2   Address                                               4812 non-null   object
#  3   City                                                  4812 non-null   object
#  4   State                                                 4812 non-null   object
#  5   ZIP Code                                              4812 non-null   int64
#  6   County Name                                           4797 non-null   object
#  7   Phone Number                                          4812 non-null   int64
# ...

# %% [markdown]
# **Datatypes of each column and total number of entries**

# %%
df['Hospital Name'].nunique()
# Out:
# 4623

# %%
df['Address'].nunique()
# Out:
# 4784

# %%
df['City'].nunique()
# Out:
# 2947

# %%
df['State'].nunique()
# Out:
# 56

# %%
df['County Name'].nunique()
# Out:
# 1563

# %% [markdown]
# # State

# %%
df['State'].value_counts()
# Out:
# TX    411
# CA    343
# FL    187
# IL    180
# PA    171
# NY    171
# OH    168
# KS    137
# GA    133
# MN    131
# MI    131
# WI    126
# OK    124
# LA    121
# IN    120
# IA    116
# MO    112
# TN    107
# NC    107
# MS     95
# KY     94
# WA     91
# AL     90
# NE     89
# VA     86
# AZ     80
# CO     78
# AR     75
# NJ     66
# MA     64
# MT     62
# SC     60
# OR     60
# SD     60
# PR     52
# MD     49
# WV     49
# UT     46
# ND     44
# ID     41
# NM     41
# NV     35
# ME     33
# CT     31
# WY     28
# NH     26
# HI     23
# AK     22
# VT     14
# RI     11
# DC      8
# DE      7
# VI      2
# GU      2
# MP      1
# AS      1
# Name: State, dtype: int64

# %%
df['State'].describe()
# Out:
# count     4812
# unique      56
# top         TX
# freq       411
# Name: State, dtype: object

# %%
sns.set(rc={'figure.figsize':(30,15)})
sns.set_style('whitegrid')
sns.countplot(x='State',hue='Hospital Type',data=df,palette='icefire_r')
# Out:
# <AxesSubplot:xlabel='State', ylabel='count'>

# %% [markdown]
# **Plot comparing States with particular Hospital Types**

# %%
sns.set(rc={'figure.figsize':(30,15)})
sns.set(font_scale = 1.5)
sns.set_style('whitegrid')
sns.countplot(x='State',hue='Timeliness of care national comparison',data=df,palette='seismic')
# Out:
# <AxesSubplot:xlabel='State', ylabel='count'>

# %% [markdown]
# **Plot comparing States with Timeliness of care national comparison**

# %%
sns.set(rc={'figure.figsize':(30,15)})
sns.set_style('whitegrid')
sns.countplot(x='State',hue='Mortality national comparison',data=df,palette='RdGy')
# Out:
# <AxesSubplot:xlabel='State', ylabel='count'>

# %% [markdown]
# **Plot comparing States with Mortality national comparison**

# %%
sns.set(rc={'figure.figsize':(30,15)})
sns.set(font_scale = 1.5)
sns.set_style('whitegrid')
sns.countplot(x='State',hue='Patient experience national comparison',data=df,palette='seismic')
# Out:
# <AxesSubplot:xlabel='State', ylabel='count'>

# %% [markdown]
# **Plot comparing States with Patient experience national comparison**

# %%
sns.set(rc={'figure.figsize':(30,15)})
sns.set_style('whitegrid')
sns.countplot(x='State',hue='Hospital overall rating',data=df,palette='RdBu_r')
# Out:
# <AxesSubplot:xlabel='State', ylabel='count'>

# %% [markdown]
# **Plot comparing States with Hospital overall rating**

# %%
sns.set(rc={'figure.figsize':(30,15)})
sns.set_style('whitegrid')
sns.countplot(x='State',hue='Hospital Ownership',data=df,palette='rainbow')
# Out:
# <AxesSubplot:xlabel='State', ylabel='count'>

# %% [markdown]
# **Plot comparing States with Hospital Ownership**

# %% [markdown]
# # Hospital Type

# %%
df['Hospital Type'].value_counts()
# Out:
# Acute Care Hospitals         3369
# Critical Access Hospitals    1344
# Childrens                      99
# Name: Hospital Type, dtype: int64

# %%
plt.figure(figsize=(15,6))
explode = [0,0.1,0.1]
colors = sns.color_palette('icefire_r')
plt.pie(df['Hospital Type'].value_counts(), labels=['Acute Care Hospitals','Critical Access Hospitals','Childrens'],
colors = colors, autopct = '%0.1f%%', explode = explode, shadow = 'False',
startangle = 90)
plt.show()

# %% [markdown]
# **Pie chart representing percentage of each Hospital Type.**

# %%
plt.figure(figsize=(14,6))
sns.countplot(x='Hospital Type',hue='Hospital Ownership',data=df,palette='seismic')
# Out:
# <AxesSubplot:xlabel='Hospital Type', ylabel='count'>

# %% [markdown]
# **Plot reperesenting Hospital Type with respect to Hospital Ownership.**

# %%
plt.figure(figsize=(14,6))
sns.countplot(x='Hospital Type',hue='Emergency Services',data=df,palette='seismic')
# Out:
# <AxesSubplot:xlabel='Hospital Type', ylabel='count'>

# %% [markdown]
# **Plot reperesenting Hospital Type with respect to Emergency Services.**

# %%
plt.figure(figsize=(14,6))
sns.countplot(x='Hospital Type',hue='Meets criteria for meaningful use of EHRs',data=df,palette='seismic')
# Out:
# <AxesSubplot:xlabel='Hospital Type', ylabel='count'>

# %% [markdown]
# **Plot reperesenting Hospital Type with respect to column- Meets criteria for meaningful use of EHRs.**

# %%
plt.figure(figsize=(14,6))
sns.countplot(x='Hospital Type',hue='Hospital overall rating',data=df,palette='seismic')
# Out:
# <AxesSubplot:xlabel='Hospital Type', ylabel='count'>

# %% [markdown]
# **Plot reperesenting Hospital Type with respect to Hospital overall rating.**

# %%
plt.figure(figsize=(14,6))
sns.countplot(x='Hospital Type',hue='Mortality national comparison',data=df,palette='seismic')
# Out:
# <AxesSubplot:xlabel='Hospital Type', ylabel='count'>

# %% [markdown]
# **Plot reperesenting Hospital Type with respect to Mortality national comparison.**

# %%
plt.figure(figsize=(14,6))
sns.countplot(x='Hospital Type',hue='Safety of care national comparison',data=df,palette='seismic')
# Out:
# <AxesSubplot:xlabel='Hospital Type', ylabel='count'>

# %% [markdown]
# **Plot reperesenting Hospital Type with respect to Safety of care national comparison.**

# %%
plt.figure(figsize=(14,6))
sns.countplot(x='Hospital Type',hue='Readmission national comparison',data=df,palette='seismic')
# Out:
# <AxesSubplot:xlabel='Hospital Type', ylabel='count'>

# %% [markdown]
# **Plot reperesenting Hospital Type with respect to Readmission national comparison.**

# %%
plt.figure(figsize=(14,6))
sns.countplot(x='Hospital Type',hue='Patient experience national comparison',data=df,palette='seismic')
# Out:
# <AxesSubplot:xlabel='Hospital Type', ylabel='count'>

# %% [markdown]
# **Plot reperesenting Hospital Type with respect to Patient experience national comparison.**

# %%
plt.figure(figsize=(14,6))
sns.countplot(x='Hospital Type',hue='Effectiveness of care national comparison',data=df,palette='seismic')
# Out:
# <AxesSubplot:xlabel='Hospital Type', ylabel='count'>

# %% [markdown]
# **Plot reperesenting Hospital Type with respect to Effectiveness of care national comparison.**

# %%
plt.figure(figsize=(14,6))
sns.countplot(x='Hospital Type',hue='Timeliness of care national comparison',data=df,palette='seismic')
# Out:
# <AxesSubplot:xlabel='Hospital Type', ylabel='count'>

# %% [markdown]
# **Plot reperesenting Hospital Type with respect to Timeliness of care national comparison.**

# %%
plt.figure(figsize=(14,6))
sns.countplot(x='Hospital Type',hue='Efficient use of medical imaging national comparison',data=df,palette='seismic')
# Out:
# <AxesSubplot:xlabel='Hospital Type', ylabel='count'>

# %% [markdown]
# **Plot reperesenting Hospital Type with respect to column-Efficient use of medical imaging national comparison.**

# %% [markdown]
# # Hospital Ownership

# %%
df['Hospital Ownership'].value_counts()
# Out:
# Voluntary non-profit - Private                 2052
# Proprietary                                     800
# Government - Hospital District or Authority     561
# Voluntary non-profit - Other                    462
# Government - Local                              407
# Voluntary non-profit - Church                   343
# Physician                                        68
# Government - State                               65
# Government - Federal                             45
# Tribal                                            9
# Name: Hospital Ownership, dtype: int64

# %%
plt.figure(figsize=(14,6))
sns.countplot(y='Hospital Ownership',data=df,palette='cividis')
# Out:
# <AxesSubplot:xlabel='count', ylabel='Hospital Ownership'>

# %% [markdown]
# **Countplot on Hospital Ownership.**

# %%
plt.figure(figsize=(15,6))
explode = [0,0.3,0.3,0.3,0,0.3,0.3,0.3,0.3,1]
colors = sns.color_palette('cividis')
plt.pie(df['Hospital Ownership'].value_counts(), labels=['Voluntary non-profit - Private','Proprietary','Government - Hospital District or Authority','Voluntary non-profit - Other','Government - Local','Voluntary non-profit - Church','Physician','Government - State','Government - Federal','Tribal'],
colors = colors, autopct = '%0.1f%%', explode = explode, shadow = 'False',
startangle = 90)
plt.show()

# %% [markdown]
# **Pie chart representing percentage of each type of Hospital Ownership.**

# %%
byownership= df.groupby(by='Hospital Ownership').count()
byownership
# Out:
#                                              Provider ID  Hospital Name  \
# Hospital Ownership
# Government - Federal                                  45             45
# Government - Hospital District or Authority          561            561
# Government - Local                                   407            407
# Government - State                                    65             65
# Physician                                             68             68
# Proprietary                                          800            800
# Tribal                                                 9              9
# Voluntary non-profit - Church                        343            343
# Voluntary non-profit - Other                         462            462
# Voluntary non-profit - Private                      2052           2052
#
#                                              Address  City  State  ZIP Code  \
# Hospital Ownership
# ...

# %% [markdown]
# **Groupby count on column Hospital Ownership**

# %% [markdown]
# # Emergency Services

# %%
df['Emergency Services'].value_counts()
# Out:
# Yes    4497
# No      315
# Name: Emergency Services, dtype: int64

# %%
df['Emergency Services'].hist(color='blue')
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Histogram on column-Emergency Services**

# %% [markdown]
# # Meets criteria for meaningful use of EHRs

# %%
df['Meets criteria for meaningful use of EHRs'].value_counts()
# Out:
# Y                4668
# Not Available       1
# Name: Meets criteria for meaningful use of EHRs, dtype: int64

# %% [markdown]
# **Value counts of column-Meets criteria for meaningful use of EHRs**

# %% [markdown]
# # Hospital overall rating

# %%
df['Hospital overall rating'].value_counts()
# Out:
# 3                1761
# Not Available    1245
# 4                 939
# 2                 678
# 1                 107
# 5                  82
# Name: Hospital overall rating, dtype: int64

# %%
df['Hospital overall rating'].describe()
# Out:
# count     4812
# unique       6
# top          3
# freq      1761
# Name: Hospital overall rating, dtype: object

# %%
plt.figure(figsize=(14,6))
sns.countplot(x='Hospital overall rating',data=df,palette='flare_r')
# Out:
# <AxesSubplot:xlabel='Hospital overall rating', ylabel='count'>

# %% [markdown]
# **Countplot on column-Hospital overall rating**

# %%
r5=df[df['Hospital overall rating']=='5']
r5
# Out:
#       Provider ID                            Hospital Name  \
# 23          10044           MARION REGIONAL MEDICAL CENTER
# 65          10125              LAKELAND COMMUNITY HOSPITAL
# 76          10149              BAPTIST MEDICAL CENTER EAST
# 145         30103                     MAYO CLINIC HOSPITAL
# 146         30105                    BANNER HEART HOSPITAL
# ...           ...                                      ...
# 4617       520083  SSM HEALTH ST MARY'S HOSPITAL - MADISON
# 4620       520089              UNITYPOINT HEALTH - MERITER
# 4622       520095                    SAUK PRAIRIE HOSPITAL
# 4749       670025          THE HEART HOSPITAL BAYLOR PLANO
# 4761       670055             METHODIST STONE OAK HOSPITAL
#
#                          Address            City State  ZIP Code County Name  \
# 23    1256 MILITARY STREET SOUTH        HAMILTON    AL     35570      MARION
# 65           42024 HIGHWAY 195 E      HALEYVILLE    AL     35565     WINSTON
# ...

# %% [markdown]
# **List of Hospitals who have Overall Rating-5**

# %%
df[df['Hospital overall rating']=='4']
# Out:
#       Provider ID                                      Hospital Name  \
# 10          10021                                DALE MEDICAL CENTER
# 11          10022                            CHEROKEE MEDICAL CENTER
# 14          10029                        EAST ALABAMA MEDICAL CENTER
# 15          10032                                   WEDOWEE HOSPITAL
# 17          10034                             COMMUNITY HOSPITAL INC
# ...           ...                                                ...
# 4777       670078                         BAPTIST EMERGENCY HOSPITAL
# 4779       670080                SETON MEDICAL CENTER HARKER HEIGHTS
# 4780       670082   BAYLOR SCOTT AND WHITE  MEDICAL CENTER  MCKINNEY
# 4782       670085    TEXAS HEALTH HARRIS METHODIST HOSPITAL ALLIANCE
# 4784       670088  BAYLOR SCOTT & WHITE MEDICAL CENTER- COLLEGE S...
#
#                              Address             City State  ZIP Code  \
# ...

# %% [markdown]
# **List of Hospitals who have Overall Rating-4**

# %%
df[df['Hospital overall rating']=='1']
# Out:
#       Provider ID                                   Hospital Name  \
# 122         30043                     CANYON VISTA MEDICAL CENTER
# 126         30064  BANNER-UNIVERSITY MEDICAL CENTER TUCSON CAMPUS
# 158         30121               MOUNTAIN VISTA MEDICAL CENTER, LP
# 192         40016                             UAMS MEDICAL CENTER
# 196         40020                      ST BERNARDS MEDICAL CENTER
# ...           ...                                             ...
# 3885       440067                       LAKEWAY REGIONAL HOSPITAL
# 3906       440137                  TENNOVA HEALTHCARE-SHELBYVILLE
# 3954       450002                    PROVIDENCE MEMORIAL HOSPITAL
# 4030       450213                        UNIVERSITY HEALTH SYSTEM
# 4396       490075                DANVILLE REGIONAL MEDICAL CENTER
#
#                                      Address          City State  ZIP Code  \
# 122                     5700 EAST HIGHWAY 90  SIERRA VISTA    AZ     85635
# ...

# %% [markdown]
# **List of Hospitals who have Overall Rating-1**

# %% [markdown]
# # Mortality national comparison

# %%
df['Mortality national comparison'].value_counts()
# Out:
# Same as the national average    2719
# Not Available                   1352
# Above the national average       400
# Below the national average       341
# Name: Mortality national comparison, dtype: int64

# %%
df['Mortality national comparison'].describe()
# Out:
# count                             4812
# unique                               4
# top       Same as the national average
# freq                              2719
# Name: Mortality national comparison, dtype: object

# %%
plt.figure(figsize=(14,6))
sns.countplot(x='Mortality national comparison',data=df,palette='flare')
# Out:
# <AxesSubplot:xlabel='Mortality national comparison', ylabel='count'>

# %% [markdown]
# **Countplot on column-Mortality national comparison**

# %%
df[df['Mortality national comparison']=='Above the national average']
# Out:
#       Provider ID                                      Hospital Name  \
# 65          10125                        LAKELAND COMMUNITY HOSPITAL
# 116         30024           ST. JOSEPH'S HOSPITAL AND MEDICAL CENTER
# 119         30036                   CHANDLER REGIONAL MEDICAL CENTER
# 123         30055                    KINGMAN REGIONAL MEDICAL CENTER
# 139         30088                      BANNER BAYWOOD MEDICAL CENTER
# ...           ...                                                ...
# 4557       510070                           RALEIGH GENERAL HOSPITAL
# 4616       520078  WHEATON FRANCISCAN HEALTHCARE ST FRANCIS HOSPITAL
# 4620       520089                        UNITYPOINT HEALTH - MERITER
# 4637       520138                     AURORA ST LUKES MEDICAL CENTER
# 4748       670024                       NORTH CYPRESS MEDICAL CENTER
#
#                        Address        City State  ZIP Code County Name  \
# ...

# %% [markdown]
# **List of Hospitals who have Mortality national comparison-Above the national average**

# %%
df[df['Mortality national comparison']=='Below the national average']
# Out:
#       Provider ID                                     Hospital Name  \
# 1           10005                     MARSHALL MEDICAL CENTER SOUTH
# 2           10006                    ELIZA COFFEE MEMORIAL HOSPITAL
# 6           10012                    DEKALB REGIONAL MEDICAL CENTER
# 9           10019                    HELEN KELLER MEMORIAL HOSPITAL
# 12          10023                      BAPTIST MEDICAL CENTER SOUTH
# ...           ...                                               ...
# 4626       520100                          BELOIT MEMORIAL HOSPITAL
# 4628       520103                       COMMUNITY MEMORIAL HOSPITAL
# 4639       520160  THEDACARE REGIONAL MEDICAL CENTER - APPLETON INC
# 4717       530012                            WYOMING MEDICAL CENTER
# 4809       650001                  GUAM MEMORIAL HOSPITAL AUTHORITY
#
#                             Address             City State  ZIP Code  \
# 1        2505 U S HIGHWAY 431 NORTH             BOAZ    AL     35957
# ...

# %% [markdown]
# **List of Hospitals who have Mortality national comparison-Below the national average**

# %% [markdown]
# # Safety of care national comparison

# %%
df['Safety of care national comparison'].value_counts()
# Out:
# Not Available                   2168
# Same as the national average    1194
# Above the national average       786
# Below the national average       664
# Name: Safety of care national comparison, dtype: int64

# %%
df['Safety of care national comparison'].describe()
# Out:
# count              4812
# unique                4
# top       Not Available
# freq               2168
# Name: Safety of care national comparison, dtype: object

# %%
plt.figure(figsize=(14,6))
sns.countplot(x='Safety of care national comparison',data=df,palette='gist_heat')
# Out:
# <AxesSubplot:xlabel='Safety of care national comparison', ylabel='count'>

# %% [markdown]
# **Countplot on column-Safety of care national comparison**

# %%
df[df['Safety of care national comparison']=='Above the national average']
# Out:
#       Provider ID                                     Hospital Name  \
# 0           10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 7           10016                     SHELBY BAPTIST MEDICAL CENTER
# 12          10023                      BAPTIST MEDICAL CENTER SOUTH
# 13          10024                     JACKSON HOSPITAL & CLINIC INC
# 14          10029                       EAST ALABAMA MEDICAL CENTER
# ...           ...                                               ...
# 4765       670060   BAYLOR SCOTT AND WHITE MEDICAL CENTER SUNNYVALE
# 4776       670077                   HOUSTON METHODIST WEST HOSPITAL
# 4778       670079              LAKEWAY REGIONAL MEDICAL CENTER, LLC
# 4779       670080               SETON MEDICAL CENTER HARKER HEIGHTS
# 4780       670082  BAYLOR SCOTT AND WHITE  MEDICAL CENTER  MCKINNEY
#
#                              Address            City State  ZIP Code  \
# 0             1108 ROSS CLARK CIRCLE          DOTHAN    AL     36301
# ...

# %% [markdown]
# **List of Hospitals who have Safety of care national comparison-Above the national average**

# %%
df[df['Safety of care national comparison']=='Below the national average']
# Out:
#       Provider ID                          Hospital Name  \
# 5           10011                      ST VINCENT'S EAST
# 9           10019         HELEN KELLER MEMORIAL HOSPITAL
# 19          10036            ANDALUSIA REGIONAL HOSPITAL
# 22          10040        GADSDEN REGIONAL MEDICAL CENTER
# 31          10056                ST VINCENT'S BIRMINGHAM
# ...           ...                                    ...
# 4640       520177   FROEDTERT MEMORIAL LUTHERAN HOSPITAL
# 4651       520207                  AURORA MEDICAL CENTER
# 4752       670041        SETON MEDICAL CENTER WILLIAMSON
# 4757       670047  SIERRA PROVIDENCE EAST MEDICAL CENTER
# 4774       670075      ST LUKE'S HOSPITAL AT THE VINTAGE
#
#                            Address        City State  ZIP Code County Name  \
# 5       50 MEDICAL PARK EAST DRIVE  BIRMINGHAM    AL     35235   JEFFERSON
# 9     1300 SOUTH MONTGOMERY AVENUE   SHEFFIELD    AL     35660     COLBERT
# ...

# %% [markdown]
# **List of Hospitals who have Safety of care national comparison-Below the national average**

# %% [markdown]
# # Readmission national comparison

# %%
df['Readmission national comparison'].value_counts()
# Out:
# Same as the national average    2119
# Not Available                   1017
# Below the national average       866
# Above the national average       810
# Name: Readmission national comparison, dtype: int64

# %%
df['Readmission national comparison'].describe()
# Out:
# count                             4812
# unique                               4
# top       Same as the national average
# freq                              2119
# Name: Readmission national comparison, dtype: object

# %%
df[df['Readmission national comparison']=='Above the national average']
# Out:
#       Provider ID                                    Hospital Name  \
# 1           10005                    MARSHALL MEDICAL CENTER SOUTH
# 7           10016                    SHELBY BAPTIST MEDICAL CENTER
# 13          10024                    JACKSON HOSPITAL & CLINIC INC
# 14          10029                      EAST ALABAMA MEDICAL CENTER
# 21          10039                              HUNTSVILLE HOSPITAL
# ...           ...                                              ...
# 4759       670053                    ST LUKE'S SUGAR LAND HOSPITAL
# 4761       670055                     METHODIST STONE OAK HOSPITAL
# 4765       670060  BAYLOR SCOTT AND WHITE MEDICAL CENTER SUNNYVALE
# 4776       670077                  HOUSTON METHODIST WEST HOSPITAL
# 4791       670096            BAY AREA REGIONAL MEDICAL CENTER, LLC
#
#                          Address         City State  ZIP Code County Name  \
# 1     2505 U S HIGHWAY 431 NORTH         BOAZ    AL     35957    MARSHALL
# ...

# %% [markdown]
# **List of Hospitals who have Readmission national comparison-Above the national average**

# %%
df[df['Readmission national comparison']=='Below the national average']
# Out:
#       Provider ID                          Hospital Name  \
# 3           10007               MIZELL MEMORIAL HOSPITAL
# 9           10019         HELEN KELLER MEMORIAL HOSPITAL
# 16          10033         UNIVERSITY OF ALABAMA HOSPITAL
# 19          10036            ANDALUSIA REGIONAL HOSPITAL
# 22          10040        GADSDEN REGIONAL MEDICAL CENTER
# ...           ...                                    ...
# 4718       530014       CHEYENNE REGIONAL MEDICAL CENTER
# 4753       670043     CEDAR PARK REGIONAL MEDICAL CENTER
# 4757       670047  SIERRA PROVIDENCE EAST MEDICAL CENTER
# 4778       670079   LAKEWAY REGIONAL MEDICAL CENTER, LLC
# 4811       660001             COMMONWEALTH HEALTH CENTER
#
#                            Address        City State  ZIP Code County Name  \
# 3                    702 N MAIN ST         OPP    AL     36467   COVINGTON
# 9     1300 SOUTH MONTGOMERY AVENUE   SHEFFIELD    AL     35660     COLBERT
# ...

# %% [markdown]
# **List of Hospitals who have Readmission national comparison-Below the national average**

# %% [markdown]
# # Patient experience national comparison

# %%
df['Patient experience national comparison'].value_counts()
# Out:
# Not Available                   1369
# Above the national average      1214
# Same as the national average    1148
# Below the national average      1081
# Name: Patient experience national comparison, dtype: int64

# %%
df['Patient experience national comparison'].describe()
# Out:
# count              4812
# unique                4
# top       Not Available
# freq               1369
# Name: Patient experience national comparison, dtype: object

# %%
df[df['Patient experience national comparison']=='Above the national average']
# Out:
#       Provider ID                                      Hospital Name  \
# 10          10021                                DALE MEDICAL CENTER
# 11          10022                            CHEROKEE MEDICAL CENTER
# 14          10029                        EAST ALABAMA MEDICAL CENTER
# 16          10033                     UNIVERSITY OF ALABAMA HOSPITAL
# 23          10044                     MARION REGIONAL MEDICAL CENTER
# ...           ...                                                ...
# 4779       670080                SETON MEDICAL CENTER HARKER HEIGHTS
# 4780       670082   BAYLOR SCOTT AND WHITE  MEDICAL CENTER  MCKINNEY
# 4784       670088  BAYLOR SCOTT & WHITE MEDICAL CENTER- COLLEGE S...
# 4793       670098                           RESOLUTE HEALTH HOSPITAL
# 4796       670103                              MEDICAL CITY ALLIANCE
#
#                              Address             City State  ZIP Code  \
# ...

# %% [markdown]
# **List of Hospitals who have Patient experience national comparison-Above the national average**

# %%
df[df['Patient experience national comparison']=='Below the national average']
# Out:
#       Provider ID                                    Hospital Name  \
# 0           10001                 SOUTHEAST ALABAMA MEDICAL CENTER
# 2           10006                   ELIZA COFFEE MEMORIAL HOSPITAL
# 5           10011                                ST VINCENT'S EAST
# 7           10016                    SHELBY BAPTIST MEDICAL CENTER
# 9           10019                   HELEN KELLER MEMORIAL HOSPITAL
# ...           ...                                              ...
# 4765       670060  BAYLOR SCOTT AND WHITE MEDICAL CENTER SUNNYVALE
# 4774       670075                ST LUKE'S HOSPITAL AT THE VINTAGE
# 4778       670079             LAKEWAY REGIONAL MEDICAL CENTER, LLC
# 4787       670092                       WALNUT HILL MEDICAL CENTER
# 4791       670096            BAY AREA REGIONAL MEDICAL CENTER, LLC
#
#                            Address        City State  ZIP Code County Name  \
# 0           1108 ROSS CLARK CIRCLE      DOTHAN    AL     36301     HOUSTON
# ...

# %% [markdown]
# **List of Hospitals who have Patient experience national comparison-Below the national average**

# %% [markdown]
# # Effectiveness of care national comparison

# %%
df['Effectiveness of care national comparison'].value_counts()
# Out:
# Same as the national average    3238
# Not Available                   1202
# Below the national average       242
# Above the national average       130
# Name: Effectiveness of care national comparison, dtype: int64

# %%
df['Effectiveness of care national comparison'].describe()
# Out:
# count                             4812
# unique                               4
# top       Same as the national average
# freq                              3238
# Name: Effectiveness of care national comparison, dtype: object

# %%
df[df['Effectiveness of care national comparison']=='Above the national average']
# Out:
#       Provider ID                                    Hospital Name  \
# 27          10049                        MEDICAL CENTER ENTERPRISE
# 108         30010                              ST. MARY'S HOSPITAL
# 188         40010                MERCY HOSPITAL NORTHWEST ARKANSAS
# 307         50100                          SHARP MEMORIAL HOSPITAL
# 336         50140               KAISER FOUNDATION HOSPITAL FONTANA
# ...           ...                                              ...
# 4625       520098  UNIVERSITY OF WI  HOSPITALS & CLINICS AUTHORITY
# 4637       520138                   AURORA ST LUKES MEDICAL CENTER
# 4751       670034                SCOTT & WHITE HOSPITAL-ROUND ROCK
# 4754       670044      TEXAS HEALTH PRESBYTERIAN HOSPITAL ROCKWALL
# 4758       670049                NORTH CENTRAL SURGICAL CENTER LLP
#
#                                       Address        City State  ZIP Code  \
# 27                       400 N EDWARDS STREET  ENTERPRISE    AL     36330
# ...

# %% [markdown]
# **List of Hospitals who have Effectiveness of care national comparison-Above the national average**

# %%
df[df['Effectiveness of care national comparison']=='Below the national average']
# Out:
#       Provider ID                    Hospital Name  \
# 3           10007         MIZELL MEMORIAL HOSPITAL
# 5           10011                ST VINCENT'S EAST
# 22          10040  GADSDEN REGIONAL MEDICAL CENTER
# 29          10052   LAKE MARTIN COMMUNITY HOSPITAL
# 31          10056          ST VINCENT'S BIRMINGHAM
# ...           ...                              ...
# 4545       510029         THOMAS MEMORIAL HOSPITAL
# 4550       510046     PRINCETON COMMUNITY HOSPITAL
# 4581       511319         JEFFERSON MEDICAL CENTER
# 4601       520041         DIVINE SAVIOR HEALTHCARE
# 4734       531310           POWELL VALLEY HOSPITAL
#
#                          Address              City State  ZIP Code  \
# 3                  702 N MAIN ST               OPP    AL     36467
# 5     50 MEDICAL PARK EAST DRIVE        BIRMINGHAM    AL     35235
# 22          1007 GOODYEAR AVENUE           GADSDEN    AL     35903
# 29            201 MARIARDEN ROAD         DADEVILLE    AL     36853
# ...

# %% [markdown]
# **List of Hospitals who have Effectiveness of care national comparison-Below the national average**

# %% [markdown]
# # Timeliness of care national comparison

# %%
df['Timeliness of care national comparison'].value_counts()
# Out:
# Same as the national average    1554
# Not Available                   1266
# Above the national average      1088
# Below the national average       904
# Name: Timeliness of care national comparison, dtype: int64

# %%
df['Timeliness of care national comparison'].describe()
# Out:
# count                             4812
# unique                               4
# top       Same as the national average
# freq                              1554
# Name: Timeliness of care national comparison, dtype: object

# %%
df[df['Timeliness of care national comparison']=='Above the national average']
# Out:
#       Provider ID                    Hospital Name  \
# 1           10005    MARSHALL MEDICAL CENTER SOUTH
# 2           10006   ELIZA COFFEE MEMORIAL HOSPITAL
# 3           10007         MIZELL MEMORIAL HOSPITAL
# 4           10008      CRENSHAW COMMUNITY HOSPITAL
# 6           10012   DEKALB REGIONAL MEDICAL CENTER
# ...           ...                              ...
# 4787       670092       WALNUT HILL MEDICAL CENTER
# 4790       670095        EMERUS COMMUNITY HOSPITAL
# 4792       670097  BAYLOR EMERGENCY MEDICAL CENTER
# 4793       670098         RESOLUTE HEALTH HOSPITAL
# 4796       670103            MEDICAL CITY ALLIANCE
#
#                                Address           City State  ZIP Code  \
# 1           2505 U S HIGHWAY 431 NORTH           BOAZ    AL     35957
# 2                   205 MARENGO STREET       FLORENCE    AL     35631
# 3                        702 N MAIN ST            OPP    AL     36467
# ...

# %% [markdown]
# **List of Hospitals who have Timeliness of care national comparison-Above the national average**

# %%
df[df['Timeliness of care national comparison']=='Below the national average']
# Out:
#       Provider ID                        Hospital Name  \
# 7           10016        SHELBY BAPTIST MEDICAL CENTER
# 12          10023         BAPTIST MEDICAL CENTER SOUTH
# 13          10024        JACKSON HOSPITAL & CLINIC INC
# 16          10033       UNIVERSITY OF ALABAMA HOSPITAL
# 21          10039                  HUNTSVILLE HOSPITAL
# ...           ...                                  ...
# 4716       530011  MEMORIAL HOSPITAL SWEETWATER COUNTY
# 4747       670023   METHODIST MANSFIELD MEDICAL CENTER
# 4748       670024         NORTH CYPRESS MEDICAL CENTER
# 4750       670031    ST LUKE'S PATIENTS MEDICAL CENTER
# 4774       670075    ST LUKE'S HOSPITAL AT THE VINTAGE
#
#                                   Address          City State  ZIP Code  \
# 7                 1000 FIRST STREET NORTH     ALABASTER    AL     35007
# 12              2105 EAST SOUTH BOULEVARD    MONTGOMERY    AL     36116
# 13                       1725 PINE STREET    MONTGOMERY    AL     36106
# ...

# %% [markdown]
# **List of Hospitals who have Timeliness of care national comparison-Below the national average**

# %% [markdown]
# # Efficient use of medical imaging national comparison

# %%
df['Efficient use of medical imaging national comparison'].value_counts()
# Out:
# Same as the national average    2051
# Not Available                   2033
# Below the national average       370
# Above the national average       358
# Name: Efficient use of medical imaging national comparison, dtype: int64

# %%
df['Efficient use of medical imaging national comparison'].describe()
# Out:
# count                             4812
# unique                               4
# top       Same as the national average
# freq                              2051
# Name: Efficient use of medical imaging national comparison, dtype: object

# %%
df[df['Efficient use of medical imaging national comparison']=='Above the national average']
# Out:
#       Provider ID                                    Hospital Name  \
# 12          10023                     BAPTIST MEDICAL CENTER SOUTH
# 48          10092                    D C H REGIONAL MEDICAL CENTER
# 107         30007                      VERDE VALLEY MEDICAL CENTER
# 119         30036                 CHANDLER REGIONAL MEDICAL CENTER
# 121         30038                 SCOTTSDALE OSBORN MEDICAL CENTER
# ...           ...                                              ...
# 4611       520066                         MERCY HEALTH SYSTEM CORP
# 4625       520098  UNIVERSITY OF WI  HOSPITALS & CLINICS AUTHORITY
# 4640       520177             FROEDTERT MEMORIAL LUTHERAN HOSPITAL
# 4717       530012                           WYOMING MEDICAL CENTER
# 4777       670078                       BAPTIST EMERGENCY HOSPITAL
#
#                             Address         City State  ZIP Code County Name  \
# 12        2105 EAST SOUTH BOULEVARD   MONTGOMERY    AL     36116  MONTGOMERY
# ...

# %% [markdown]
# **List of Hospitals who have Efficient use of medical imaging national comparison-Above the national average**

# %%
df[df['Efficient use of medical imaging national comparison']=='Below the national average']
# Out:
#       Provider ID                                      Hospital Name  \
# 1           10005                      MARSHALL MEDICAL CENTER SOUTH
# 7           10016                      SHELBY BAPTIST MEDICAL CENTER
# 9           10019                     HELEN KELLER MEMORIAL HOSPITAL
# 16          10033                     UNIVERSITY OF ALABAMA HOSPITAL
# 21          10039                                HUNTSVILLE HOSPITAL
# ...           ...                                                ...
# 4626       520100                           BELOIT MEMORIAL HOSPITAL
# 4713       530002                  CAMPBELL COUNTY MEMORIAL HOSPITAL
# 4720       530025                          IVINSON MEMORIAL HOSPITAL
# 4748       670024                       NORTH CYPRESS MEDICAL CENTER
# 4775       670076  BAYLOR SCOTT AND WHITE SURGICAL HOSPITAL AT SH...
#
#                            Address        City State  ZIP Code County Name  \
# ...

# %% [markdown]
# **List of Hospitals who have Efficient use of medical imaging national comparison-Below the national average**

# %% [markdown]
# # Top Hospitals

# %%
r5[r5['Patient experience national comparison']=='Above the national average']
# Out:
#       Provider ID                            Hospital Name  \
# 23          10044           MARION REGIONAL MEDICAL CENTER
# 76          10149              BAPTIST MEDICAL CENTER EAST
# 145         30103                     MAYO CLINIC HOSPITAL
# 146         30105                    BANNER HEART HOSPITAL
# 225         40147               ARKANSAS SURGICAL HOSPITAL
# ...           ...                                      ...
# 4617       520083  SSM HEALTH ST MARY'S HOSPITAL - MADISON
# 4620       520089              UNITYPOINT HEALTH - MERITER
# 4622       520095                    SAUK PRAIRIE HOSPITAL
# 4749       670025          THE HEART HOSPITAL BAYLOR PLANO
# 4761       670055             METHODIST STONE OAK HOSPITAL
#
#                          Address            City State  ZIP Code County Name  \
# 23    1256 MILITARY STREET SOUTH        HAMILTON    AL     35570      MARION
# 76               400 TAYLOR ROAD      MONTGOMERY    AL     36117  MONTGOMERY
# ...

# %% [markdown]
# **List of Top Hospitals who have rating 5 and Patient experience national comparison is Above the national average**

# %% [markdown]
# # Conclusion
